# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd #basic data operations 
import numpy as np
import re #for using regex functions
import seaborn as sns
import matplotlib.pyplot as plt # for visualization of data
from matplotlib import style   # to set style for the plots
style.use('ggplot') # ggplot is used here 
from sklearn.feature_extraction.text import CountVectorizer #to vectorize the text document
from sklearn.model_selection import train_test_split #to train the texting data
from sklearn.linear_model import LogisticRegression #to perform logistic regression on the data

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay  #different evaluation model for evaluation
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


import warnings
warnings.filterwarnings("ignore")

# %%
text_df = pd.read_csv('TSA-Preprocessing-dropped.csv')  #to load the data

# %%
text_df.head()
# Out:
#                                                 text  polarity sentiment
# 0  folks said daikon paste could treat cytokine s...       0.0   Neutral
# 1  world wrong side history year hopefully bigges...      -0.5  Negative
# 2  coronavirus sputnikv astrazeneca pfizerbiontec...       0.0   Neutral
# 3  facts immutable senator even youre ethically s...       0.1  Positive
# 4  explain need vaccine borisjohnson matthancock ...       0.0   Neutral

# %%
text_df
# Out:
#                                                      text  polarity sentiment
# 0       folks said daikon paste could treat cytokine s...       0.0   Neutral
# 1       world wrong side history year hopefully bigges...      -0.5  Negative
# 2       coronavirus sputnikv astrazeneca pfizerbiontec...       0.0   Neutral
# 3       facts immutable senator even youre ethically s...       0.1  Positive
# 4       explain need vaccine borisjohnson matthancock ...       0.0   Neutral
# ...                                                   ...       ...       ...
# 211766  45 urban bengaluru covidvaccine availability 1...       0.2  Positive
# 211767  1844 bbmp bengaluru covidvaccine availability ...       0.4  Positive
# 211768  1844 urban bengaluru covidvaccine availability...       0.2  Positive
# 211769  promote vaccines leaving stronger russia vacci...       0.0   Neutral
# 211770  45 urban bengaluru covidvaccine availability 1...       0.2  Positive
#
# [211771 rows x 3 columns]

# %% [markdown]
# ### Count-Vectorization

# %%
vect = CountVectorizer(ngram_range=(1,2)).fit(text_df['text'])

# %% [markdown]
# ### Creating the Biagram Model

# %%
X = text_df['text']
Y = text_df['sentiment']
X = vect.transform(X)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("Size of x_train:", (x_train.shape))
print("Size of y_train:", (y_train.shape))
print("Size of x_test:", (x_test.shape))
print("Size of y_test:", (y_test.shape))
# Out:
# Size of x_train: (169416, 897583)
# Size of y_train: (169416,)
# Size of x_test: (42355, 897583)
# Size of y_test: (42355,)

# %% [markdown]
# # Applying Models

# %% [markdown]
# # Logistic Regression

# %%
logreg = LogisticRegression()
logreg_model = logreg.fit(x_train, y_train)
logreg_pred = logreg_model.predict(x_test)
logreg_acc = accuracy_score(logreg_pred, y_test)
print("Test accuracy: {:.2f}%".format(logreg_acc*100))
# Out:
# Test accuracy: 96.66%

# %%
print(confusion_matrix(y_test, logreg_pred))
print("\n")
print(classification_report(y_test, logreg_pred))
# Out:
# [[ 3589   449   265]
#  [   28 23975    78]
#  [  148   446 13377]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.83      0.89      4303
#      Neutral       0.96      1.00      0.98     24081
#     Positive       0.97      0.96      0.97     13971
#
#     accuracy                           0.97     42355
#    macro avg       0.96      0.93      0.95     42355
# weighted avg       0.97      0.97      0.97     42355

# %%
style.use('classic')
cm = confusion_matrix(y_test, logreg_pred, labels=logreg.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=logreg.classes_)
disp.plot()

# %% [markdown]
# # Naive Byes

# %%
nb = MultinomialNB(alpha=1.0,fit_prior=True,class_prior=None)

nb_model = nb.fit(x_train, y_train)

nb_pred = nb_model.predict(x_test)

print("Test Accuracy: ", round(accuracy_score(y_test, nb_pred)*100,2), "\b%")
print("\n")
print(confusion_matrix(y_test, nb_pred))
print("\n")
print("Classification Report:\n\n", classification_report(y_test, nb_pred))
# Out:
# Test Accuracy:  77.69%
#
#
# [[ 2119   400  1784]
#  [ 1216 17407  5458]
#  [  271   319 13381]]
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#     Negative       0.59      0.49      0.54      4303
#      Neutral       0.96      0.72      0.82     24081
#     Positive       0.65      0.96      0.77     13971
#
#     accuracy                           0.78     42355
#    macro avg       0.73      0.72      0.71     42355
# weighted avg       0.82      0.78      0.78     42355

# %%
style.use('classic')
cm = confusion_matrix(y_test, nb_pred, labels=nb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=nb.classes_)
disp.plot()

# %% [markdown]
# # SVM

# %%
# Train an SVM classifier on the training set
clf = LinearSVC()
sv_model = clf.fit(x_train, y_train)

# Evaluate the model's performance on the testing set
sv_pred = sv_model.predict(x_test)
print("Test Accuracy:", round(accuracy_score(y_test, sv_pred)*100,2), "\b%")
print("\n")
print(confusion_matrix(y_test, sv_pred))
print("\n")
print("Classification Report:\n\n", classification_report(y_test, sv_pred))
# Out:
# Test Accuracy: 97.85%
#
#
# [[ 3855   224   224]
#  [   30 23978    73]
#  [  136   222 13613]]
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#     Negative       0.96      0.90      0.93      4303
#      Neutral       0.98      1.00      0.99     24081
#     Positive       0.98      0.97      0.98     13971
#
#     accuracy                           0.98     42355
#    macro avg       0.97      0.96      0.96     42355
# weighted avg       0.98      0.98      0.98     42355

# %%
style.use('classic')
cm = confusion_matrix(y_test, sv_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=clf.classes_)
disp.plot()

# %% [markdown]
# # KNN

# %%
kn = KNeighborsClassifier(n_neighbors=3)

kn_model = kn.fit(x_train, y_train)

kn_pred = kn_model.predict(x_test)

print("Test Accuracy: ", round(accuracy_score(y_test, kn_pred)*100,2), "\b%")
print("\n")
print(confusion_matrix(y_test, kn_pred))
print("\n")
print("Classification Report:\n\n", classification_report(y_test, kn_pred, labels=["real", "fake"]))
# Out:
# Test Accuracy:  68.75%
#
#
# [[  733  3476    94]
#  [   25 23935   121]
#  [   32  9486  4453]]
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#         real       0.00      0.00      0.00         0
#         fake       0.00      0.00      0.00         0
#
#    micro avg       0.00      0.00      0.00         0
#    macro avg       0.00      0.00      0.00         0
# weighted avg       0.00      0.00      0.00         0

# %%
style.use('classic')
cm = confusion_matrix(y_test, kn_pred, labels=kn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=kn.classes_)
disp.plot()

# %% [markdown]
# # Decision Tree

# %%
dtc = DecisionTreeClassifier(criterion= 'entropy',max_depth = 1000, splitter='best', random_state=100)
dtc_model = dtc.fit(x_train, y_train)

dtc_pred = dtc_model.predict(x_test)

print("Test Accuracy: ", round(accuracy_score(y_test, dtc_pred)*100,2), "\b%")
print("\n")
print(confusion_matrix(y_test, dtc_pred))
print("\n")
print("Classification Report:\n\n", classification_report(y_test, dtc_pred))
# Out:
# Test Accuracy:  97.16%
#
#
# [[ 3695   163   445]
#  [   33 23970    78]
#  [  291   192 13488]]
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#     Negative       0.92      0.86      0.89      4303
#      Neutral       0.99      1.00      0.99     24081
#     Positive       0.96      0.97      0.96     13971
#
#     accuracy                           0.97     42355
#    macro avg       0.96      0.94      0.95     42355
# weighted avg       0.97      0.97      0.97     42355

# %%
style.use('classic')
cm = confusion_matrix(y_test, dtc_pred, labels=dtc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=dtc.classes_)
disp.plot()

# %% [markdown]
# # RF

# %%
rf = RandomForestClassifier(max_depth = 1000, random_state=42,n_estimators=100,criterion="entropy")

# Train the model on the training set
rf_model = rf.fit(x_train, y_train)

# %%
# Make predictions on the test set
rf_pred = rf.predict(x_test)

print("Test accuracy:", round(accuracy_score(y_test, rf_pred)*100,2), "\b%")
print("\n")
print(confusion_matrix(y_test, rf_pred))
print("\n")
print("Classification Report:\n\n", classification_report(y_test, rf_pred))
# Out:
# Test accuracy: 91.32%
#
#
# [[ 2451  1378   474]
#  [   14 23994    73]
#  [   99  1637 12235]]
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#     Negative       0.96      0.57      0.71      4303
#      Neutral       0.89      1.00      0.94     24081
#     Positive       0.96      0.88      0.91     13971
#
#     accuracy                           0.91     42355
#    macro avg       0.93      0.81      0.86     42355
# weighted avg       0.92      0.91      0.91     42355

# %%
style.use('classic')
cm = confusion_matrix(y_test, rf_pred, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=rf.classes_)
disp.plot()

# %% [markdown]
# #  Store the model names and their accuracy in a dataframe

# %%
res = []
res = pd.DataFrame(res)
res["models"] = ["Logistic Regression", "Naive Bayes","SVM",  "KNN", "Decision Tree", "Random Forest"]
res["accuracy"] = [ round(accuracy_score(y_test, logreg_pred)*100,2),round(accuracy_score(y_test, nb_pred)*100,2),round(accuracy_score(y_test, sv_pred)*100,2), round(accuracy_score(y_test, kn_pred)*100,2), round(accuracy_score(y_test, dtc_pred)*100,2), round(accuracy_score(y_test, rf_pred)*100,2)]
res = res.sort_values("accuracy", ascending=False).reset_index(drop=True)
res.to_csv('model_results.csv', index=False)
res
# Out:
#                 models  accuracy
# 0                  SVM     97.85
# 1        Decision Tree     97.16
# 2  Logistic Regression     96.66
# 3        Random Forest     91.32
# 4          Naive Bayes     77.69
# 5                  KNN     68.75

# %% [markdown]
# #  Save the traied models locally

# %%
import joblib

joblib.dump(logreg_model, 'Trained Models/logregr_model.pkl')
joblib.dump(nb_model, 'Trained Models/nb_model.pkl')
joblib.dump(sv_model, 'Trained Models/svm_model.pkl')
joblib.dump(kn_model, 'Trained Models/kn_model.pkl')
joblib.dump(dtc_model, 'Trained Models/dtc_model.pkl')
joblib.dump(rf_model, 'Trained Models/rf_model.pkl')
# Out:
# ['Trained Models/rf_model.pkl']
